# %% [markdown]
# # Summary Exercise

# %% [markdown]
# Now that your are familiar with some of the main Python libraries, you will have the opportunity to use them to try to solve a complex chemistry problem.
# Click on this {download}`link<./IR_data.zip>` to download a datafile containing simulated Infrared (IR) Spectra of many molecules (the dataset comes from a [publication](https://pubs.acs.org/doi/10.1021/acs.jchemed.1c00693) in the Journal of Chemical Education). The file looks like this:

# %%
# Code for finding the data file and showing the first lines
import os
import sys
sys.path.append(os.path.abspath("./content"))
import pandas as pd
df = pd.read_csv("IR_data.csv")
df.head(5)
# Out:
#           SMILES                              name       500       502  \
# 0      COC1OCCO1            2-methoxy-13-dioxolane  0.000051  0.000051
# 1       CCCCCC=O                           hexanal  0.000121  0.000126
# 2   CC1CCC(C)C1C  1R2R3S-123-trimethylcyclopentane  0.000013  0.000013
# 3     c1cn[se]c1                     12-selenazole  0.000243  0.000244
# 4  CCC(C)=CC(C)C           3E-24-dimethylhex-3-ene  0.000053  0.000053
#
#         504       506       508       510       512       514  ...      3982  \
# 0  0.000052  0.000052  0.000053  0.000053  0.000054  0.000054  ...  0.000005
# 1  0.000131  0.000136  0.000141  0.000146  0.000151  0.000155  ...  0.000008
# 2  0.000013  0.000013  0.000012  0.000012  0.000012  0.000012  ...  0.000013
# 3  0.000245  0.000246  0.000248  0.000249  0.000251  0.000254  ...  0.000003
# 4  0.000053  0.000054  0.000054  0.000054  0.000054  0.000055  ...  0.000012
#
#        3984      3986      3988      3990      3992      3994      3996  \
# ...

# %% [markdown]
# Each row corresponds to a molecule. For each molecule, you have the molecule name, the SMILES code of the molecule, and the rest of the columns correspond to the infrared light absorbance at specific wavenumbers (given in the title of the columns, in $cm^{-1}$). From this dataset, try to determine what is the spectral signature of carbonyl functional groups, i.e. where does these groups absorb IR. Of course, the problem can be solved by using the different libraries we have seen in this lecture section. You have the right to use anything you want to help you, including web search and AI. Good luck!
