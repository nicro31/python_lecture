# %% [markdown]
# # TEST

# %% [markdown]
# Please download

# %%
x = 3
x
# Out:
# 3

# %%
print(x*5)
# Out:
# 15

# %% [markdown]
# ```{admonition} Exercice 1
# :class: tip
# :label: my-exercice2
# Calculez la moyenne des nombres suivants : [1, 2, 3, 4, 5]
# ```

# %% [markdown]
# ```{dropdown} Solution
# Voici la solution en Python :
#
# ```{code-cell} python
# s = sum(range(1, 11))
# print("Somme =", s)
# ```
# ```

# %%
print(20)
# Out:
# 15
